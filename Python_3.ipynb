# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/gender-pay-gap,-june-quarters,-1998–2023.csv")
print(df.head())
# Out:
#   Quarter  Gender pay gap
# 0  Jun-98            16.2
# 1  Jun-99            15.2
# 2  Jun-00            14.0
# 3  Jun-01            13.1
# 4  Jun-02            12.3

# %%
df.iloc[2,df.columns.get_loc('Gender pay gap')]=18.1
print(df.head())
# Out:
#   Quarter  Gender pay gap
# 0  Jun-98            16.2
# 1  Jun-99            15.2
# 2  Jun-00            18.1
# 3  Jun-01            13.1
# 4  Jun-02            12.3

# %%
df['Department']='Inventory'
print(df.tail())
# Out:
#    Quarter  Gender pay gap Department
# 21  Jun-19             9.3  Inventory
# 22  Jun-20             9.5  Inventory
# 23  Jun-21             9.1  Inventory
# 24  Jun-22             9.2  Inventory
# 25  Jun-23             8.6  Inventory

# %%
info=pd.read_csv("/content/gender-pay-gap,-june-quarters,-1998–2023.csv",index_col='Quarter')
print(info.head())
# Out:
#          Gender pay gap
# Quarter
# Jun-98             16.2
# Jun-99             15.2
# Jun-00             14.0
# Jun-01             13.1
# Jun-02             12.3

# %%
a=info['Gender pay gap']
print(a.head(4))
# Out:
# Quarter
# Jun-98    16.2
# Jun-99    15.2
# Jun-00    14.0
# Jun-01    13.1
# Name: Gender pay gap, dtype: float64

# %%
df=pd.read_csv("/content/annual-enterprise-survey-2021-financial-year-provisional-size-bands-csv.csv")
print(df.head())
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                           variable  value               unit
# 0                                    Activity unit  46134              COUNT
# 1                           Rolling mean employees      0              COUNT
# 2                          Salaries and wages paid    279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies   8187  DOLLARS(millions)
# 4                                     Total income   8866  DOLLARS(millions)

# %%
info=pd.DataFrame({'Name':['Ram','Rajat','Simran','Komal'],
                  'Year':[2001,2005,2003,2004],
                   'Leaves':[10,9,5,4]})
info
# Out:
#      Name  Year  Leaves
# 0     Ram  2001      10
# 1   Rajat  2005       9
# 2  Simran  2003       5
# 3   Komal  2004       4

# %%
info.set_index('Name')
# Out:
#         Year  Leaves
# Name
# Ram     2001      10
# Rajat   2005       9
# Simran  2003       5
# Komal   2004       4

# %%
a=pd.Series([1,2,3,4])
info.set_index([a,a**2])
# Out:
#         Name  Year  Leaves
# 1 1      Ram  2001      10
# 2 4    Rajat  2005       9
# 3 9   Simran  2003       5
# 4 16   Komal  2004       4

# %%
info.reset_index()
info
# Out:
#      Name  Year  Leaves
# 0     Ram  2001      10
# 1   Rajat  2005       9
# 2  Simran  2003       5
# 3   Komal  2004       4
